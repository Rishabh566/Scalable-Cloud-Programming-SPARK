# %% [markdown]
# # Question 6: For each day of the week, what is the average number of seconds over which ”re-synch state events” occurred?

# %% [markdown]
# # Section 1: Data Preparation and Preprocessing

# %% [markdown]
# **IMPORTING NECESSARY LIBRARIES**

# %%
#https://spark.apache.org/docs/latest/api/python/getting_started/quickstart_df.html
# Importinng 'SparkSession' module which is the main entry point for DataFrame and SQL functionality. SparkSession can be used create DataFrame, register DataFrame as tables, execute SQL over tables and cache tables.
from pyspark.sql import SparkSession

# Importing 'Date (datetime.date)', 'Timestamp (datetime.datetime)' , 'Double' data type from 'Data Types' module  
from pyspark.sql.types import DateType, TimestampType, DoubleType, IntegerType

# importing built-in functions available for DataFrame.
from pyspark.sql.functions import to_date, to_timestamp, col, month, date_format, regexp_extract, dayofweek, avg

# Importing 'matplotlib.pyplot' module for creating and customizing plots and visualizations. 
# 'pyplot' is a part of the Matplotlib library and provides a user-friendly interface to create different types of plots.
import matplotlib.pyplot as plt

# Importing'time' module for measuring execution time
import time

# Import re module which provides regular expression matching operations in Python.
# https://docs.python.org/3/library/re.html
import re

# %% [markdown]
# **EXECUTION TIME COUNTER START**

# %%
# Recording the starting time of the execution using the 'time.perf_counter()' function.It provides a high-resolution timer that measures the time elapsed in seconds to measure its execution time.
executiontimestart= time.perf_counter()

# %%
# Initializing SparkSession named 'ScpProject' using the SparkSession builder.
session = SparkSession.builder.appName('ScpProject').getOrCreate()
# Out:
# 23/08/11 21:26:49 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# Reading data from CSV file into a DataFrame 'bgl_log_df'
bgl_log_df = session.read.csv("BGLnew.log", sep=',', inferSchema=True, header=False)

# %%
# Renaming the columns 'toDF()' method for better understanding into our dataframe.
bgl_log_df = bgl_log_df.toDF('alert_message_flag', 'timestamp', 'date', 'node', 'date_and_time', 'node_repeated',
                             'message_type', 'system_component', 'level', 'message_content')

# %%
# Parsing 'date' column to standard DateType
bgl_log_df = bgl_log_df.withColumn('date', to_date('date', 'yyyy.MM.dd'))

# %%
# Parsing 'date_and_time' column to standard TimestampType
bgl_log_df = bgl_log_df.withColumn('date_and_time', to_timestamp('date_and_time', 'yyyy-MM-dd-HH.mm.ss.SSSSSS'))

# %%
# Casting columns to appropriate data types
bgl_log_df = bgl_log_df.withColumn("timestamp", bgl_log_df["timestamp"].cast(TimestampType())) \
    .withColumn("date", bgl_log_df["date"].cast(DateType())) \
    .withColumn("date_and_time", bgl_log_df["date_and_time"].cast(TimestampType()))

# %%
# Using 'printSchema()' method to display the updated schema of the DataFrame 'bgl_log_df'.
bgl_log_df.printSchema()
# Out:
# root
#  |-- alert_message_flag: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- date: date (nullable = true)
#  |-- node: string (nullable = true)
#  |-- date_and_time: timestamp (nullable = true)
#  |-- node_repeated: string (nullable = true)
#  |-- message_type: string (nullable = true)
#  |-- system_component: string (nullable = true)
#  |-- level: string (nullable = true)
#  |-- message_content: string (nullable = true)

# %%
# bgl_log_df: The DataFrame on which the operation is performed. This DataFrame contains log data with various columns like "date_and_time".
# bgl_log_df.withColumn(): A method used to add a new column to the DataFrame. It takes two arguments: the name of the new column and the expression to calculate its values.
# "day": The name of the new column that will be added to the DataFrame. This column will store the day of the week corresponding to the "date_and_time" column.
# date_format(col("date_and_time"), "EEEE"): The expression to calculate the values of the new "day" column. It uses the "date_format" function from PySpark SQL to extract the day of the week (full name) from the "date_and_time" column. The "EEEE" format string specifies the full name of the day (e.g., Monday, Tuesday, etc.).
# The result of the "date_format" function is applied to each row of the DataFrame, and the corresponding day of the week is stored in the new "day" column.
bgl_log_df = bgl_log_df.withColumn("day", date_format(col("date_and_time"), "EEEE"))

# %% [markdown]
# **DATA PREPRATION AND PREPROCESSING COMPLETED**

# %%
# We are using the 'show()' method to display the DataFrame 'bgl_log_df' in a vertical format.
# The 'vertical=True' argument is used to display the DataFrame vertically, showing each row in a single line.
# The 'truncate=False' argument is used to prevent truncation of column values, ensuring complete visibility of the data.
bgl_log_df.show(truncate=False, vertical=True)
# Out:
# -RECORD 0------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:50
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:50.363779
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 1------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:50
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:50.527847
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 2------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:50
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:50.675872
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 3------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:50
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:50.823719
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 4------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:50
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:50.982731
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 5------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.131467
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 6------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.293532
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 7------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.428563
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 8------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.601412
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 9------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.749199
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 10-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:51
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:51.885834
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 11-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.041388
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 12-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.199063
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 13-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.345821
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 14-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.493353
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 15-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.638135
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 16-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.807927
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 17-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:52
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:52.951717
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 18-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:53
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:53.12578
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# -RECORD 19-----------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-03 22:42:53
#  date               | 2005-06-03
#  node               | R02-M1-N0-C:J12-U11
#  date_and_time      | 2005-06-03 15:42:53.276129
#  node_repeated      | R02-M1-N0-C:J12-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | instruction cache parity error corrected
#  day                | Friday
# only showing top 20 rows

# %% [markdown]
# # Section 2: Log Data Analysis : Spark RDD

# %% [markdown]
# **TOTAL NUMBER OF LOG ENTRIES IN THE LOG DATASET COUNT**

# %%
# Count total logs in the DataFrame
total_logs_count = bgl_log_df.count()

# Display the total number of logs
total_logs_count
# Out:
# 4747963

# %%
# Filter the DataFrame to extract rows containing the phrase "re-synch state event" in the message_content column.
# The result will be a new DataFrame containing only the rows with the specified phrase.
extracted_logs_df = bgl_log_df.filter(col("message_content").contains("re-synch state event"))

# The `show()` method is used to display the content of the DataFrame
extracted_logs_df.show(truncate=False, vertical=True)
# Out:
# -RECORD 0---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-04 01:21:45
#  date               | 2005-06-03
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-03 18:21:45.321124
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Friday
# -RECORD 1---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-04 02:13:26
#  date               | 2005-06-03
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-03 19:13:26.552359
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Friday
# -RECORD 2---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-05 08:55:12
#  date               | 2005-06-05
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-05 01:55:12.903167
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Sunday
# -RECORD 3---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-05 08:55:13
#  date               | 2005-06-05
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-05 01:55:13.435659
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 31 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Sunday
# -RECORD 4---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:18
#  date               | 2005-06-06
#  node               | R27-M1-NB-C:J02-U11
#  date_and_time      | 2005-06-06 08:08:18.373457
#  node_repeated      | R27-M1-NB-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected
#  day                | Monday
# -RECORD 5---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:20
#  date               | 2005-06-06
#  node               | R27-M0-NA-C:J02-U11
#  date_and_time      | 2005-06-06 08:08:20.649555
#  node_repeated      | R27-M0-NA-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Monday
# -RECORD 6---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:20
#  date               | 2005-06-06
#  node               | R27-M0-NA-C:J02-U11
#  date_and_time      | 2005-06-06 08:08:20.699541
#  node_repeated      | R27-M0-NA-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Monday
# -RECORD 7---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:24
#  date               | 2005-06-06
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-06 08:08:24.750475
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 4 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Monday
# -RECORD 8---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:24
#  date               | 2005-06-06
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-06 08:08:24.78004
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 4 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Monday
# -RECORD 9---------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:25
#  date               | 2005-06-06
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-06 08:08:25.324527
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 37 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 10--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:25
#  date               | 2005-06-06
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-06-06 08:08:25.33814
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 37 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 11--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:48
#  date               | 2005-06-06
#  node               | R27-M0-NE-C:J02-U11
#  date_and_time      | 2005-06-06 08:08:48.884207
#  node_repeated      | R27-M0-NE-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected
#  day                | Monday
# -RECORD 12--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:08:57
#  date               | 2005-06-06
#  node               | R27-M0-NB-C:J02-U11
#  date_and_time      | 2005-06-06 08:08:57.849851
#  node_repeated      | R27-M0-NB-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected
#  day                | Monday
# -RECORD 13--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:01
#  date               | 2005-06-06
#  node               | R23-M0-NA-C:J02-U11
#  date_and_time      | 2005-06-06 08:09:01.458734
#  node_repeated      | R23-M0-NA-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected
#  day                | Monday
# -RECORD 14--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NB-C:J12-U01
#  date_and_time      | 2005-06-06 08:09:29.450705
#  node_repeated      | R27-M0-NB-C:J12-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 15--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NB-C:J12-U01
#  date_and_time      | 2005-06-06 08:09:29.465421
#  node_repeated      | R27-M0-NB-C:J12-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 16--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NF-C:J16-U01
#  date_and_time      | 2005-06-06 08:09:29.480468
#  node_repeated      | R27-M0-NF-C:J16-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 17--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NF-C:J16-U01
#  date_and_time      | 2005-06-06 08:09:29.495456
#  node_repeated      | R27-M0-NF-C:J16-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected
#  day                | Monday
# -RECORD 18--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NF-C:J12-U01
#  date_and_time      | 2005-06-06 08:09:29.562441
#  node_repeated      | R27-M0-NF-C:J12-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected
#  day                | Monday
# -RECORD 19--------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-06-06 15:09:29
#  date               | 2005-06-06
#  node               | R27-M0-NE-C:J13-U01
#  date_and_time      | 2005-06-06 08:09:29.656035
#  node_repeated      | R27-M0-NE-C:J13-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected
#  day                | Monday
# only showing top 20 rows

# %%
# https://learn.microsoft.com/en-us/azure/databricks/sql/language-manual/functions/regexp_extract
# Defined regular expression pattern to extract the seconds from the message_content
#pattern =r"re-synch state event(?:\(s\))? \(dcr 0x019a\) detected over (\d+) seconds"

# The pattern matches logs with the following structure:
# - "re-synch state event" followed by an optional "s" inside non-capturing group "(?:...)".
# - "(dcr 0x" followed by one or more hexadecimal digits "[0-9A-Fa-f]+" and then a closing parenthesis ")".
# - Any non-digit characters "[^0-9]+" to allow for spaces or other characters between the hexadecimal number and "seconds".
# - "(\d+)" to capture one or more digits representing the number of seconds.

pattern= r"re-synch state event(?:\(s\))? \(dcr 0x[0-9A-Fa-f]+\) detected over (\d+) seconds"

# Using the regular expression pattern to extract the number of seconds from the message_content.
# The extracted value will be stored in a new column named "seconds" in the DataFrame "extracted_logs_df".
# The extracted value is cast to an IntegerType to ensure it is represented as an integer.
extracted_logs_df = extracted_logs_df.withColumn("seconds", regexp_extract(col("message_content"), pattern, 1).cast(IntegerType()))
extracted_logs_df.show(10)
# Out:
# +------------------+-------------------+----------+-------------------+--------------------+-------------------+------------+----------------+-----+--------------------+------+-------+
# |alert_message_flag|          timestamp|      date|               node|       date_and_time|      node_repeated|message_type|system_component|level|     message_content|   day|seconds|
# +------------------+-------------------+----------+-------------------+--------------------+-------------------+------------+----------------+-----+--------------------+------+-------+
# |                 -|2005-06-04 01:21:45|2005-06-03|R06-M1-N6-C:J15-U01|2005-06-03 18:21:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|1 tree receiver 2...|Friday|   null|
# |                 -|2005-06-04 02:13:26|2005-06-03|R06-M1-N6-C:J15-U01|2005-06-03 19:13:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|1 tree receiver 2...|Friday|   null|
# |                 -|2005-06-05 08:55:12|2005-06-05|R06-M1-N6-C:J15-U01|2005-06-05 01:55:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|1 tree receiver 0...|Sunday|   null|
# |                 -|2005-06-05 08:55:13|2005-06-05|R06-M1-N6-C:J15-U01|2005-06-05 01:55:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|31 tree receiver ...|Sunday|   null|
# |                 -|2005-06-06 15:08:18|2005-06-06|R27-M1-NB-C:J02-U11|2005-06-06 08:08:...|R27-M1-NB-C:J02-U11|         RAS|          KERNEL| INFO|1 tree receiver 1...|Monday|   null|
# |                 -|2005-06-06 15:08:20|2005-06-06|R27-M0-NA-C:J02-U11|2005-06-06 08:08:...|R27-M0-NA-C:J02-U11|         RAS|          KERNEL| INFO|1 tree receiver 0...|Monday|   null|
# |                 -|2005-06-06 15:08:20|2005-06-06|R27-M0-NA-C:J02-U11|2005-06-06 08:08:...|R27-M0-NA-C:J02-U11|         RAS|          KERNEL| INFO|1 tree receiver 0...|Monday|   null|
# |                 -|2005-06-06 15:08:24|2005-06-06|R06-M1-N6-C:J15-U01|2005-06-06 08:08:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|4 tree receiver 0...|Monday|   null|
# |                 -|2005-06-06 15:08:24|2005-06-06|R06-M1-N6-C:J15-U01|2005-06-06 08:08:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|4 tree receiver 0...|Monday|   null|
# |                 -|2005-06-06 15:08:25|2005-06-06|R06-M1-N6-C:J15-U01|2005-06-06 08:08:...|R06-M1-N6-C:J15-U01|         RAS|          KERNEL| INFO|37 tree receiver ...|Monday|   null|
# +------------------+-------------------+----------+-------------------+--------------------+-------------------+------------+----------------+-----+--------------------+------+-------+
# only showing top 10 rows

# %%
#filters out rows with 'null' values in the 'seconds' column of the DataFrame 'extracted_logs_df'. 'na.drop' method is used to remove rows containing 'null' values in the specified column 'seconds'.
extracted_logs_df = extracted_logs_df.na.drop(subset=["seconds"])
extracted_logs_df.show(truncate=False, vertical=True)
# Out:
# [Stage 9:============================================>              (3 + 1) / 4]
# -RECORD 0--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:18:52
#  date               | 2005-11-15
#  node               | R02-M0-NE-C:J02-U11
#  date_and_time      | 2005-11-15 05:18:52.775116
#  node_repeated      | R02-M0-NE-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 2 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected over 388 seconds
#  day                | Tuesday
#  seconds            | 388
# -RECORD 1--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:18:53
#  date               | 2005-11-15
#  node               | R07-M1-N2-C:J02-U11
#  date_and_time      | 2005-11-15 05:18:53.547811
#  node_repeated      | R07-M1-N2-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 389 seconds
#  day                | Tuesday
#  seconds            | 389
# -RECORD 2--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:41
#  date               | 2005-11-15
#  node               | R36-M0-N7-C:J03-U11
#  date_and_time      | 2005-11-15 05:47:41.018191
#  node_repeated      | R36-M0-N7-C:J03-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 6 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 390 seconds
#  day                | Tuesday
#  seconds            | 390
# -RECORD 3--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:42
#  date               | 2005-11-15
#  node               | R55-M0-ND-C:J03-U11
#  date_and_time      | 2005-11-15 05:47:42.185481
#  node_repeated      | R55-M0-ND-C:J03-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 390 seconds
#  day                | Tuesday
#  seconds            | 390
# -RECORD 4--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:42
#  date               | 2005-11-15
#  node               | R55-M0-N9-C:J06-U11
#  date_and_time      | 2005-11-15 05:47:42.254581
#  node_repeated      | R55-M0-N9-C:J06-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected over 390 seconds
#  day                | Tuesday
#  seconds            | 390
# -RECORD 5--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:42
#  date               | 2005-11-15
#  node               | R55-M0-N9-C:J06-U11
#  date_and_time      | 2005-11-15 05:47:42.278149
#  node_repeated      | R55-M0-N9-C:J06-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 2 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 390 seconds
#  day                | Tuesday
#  seconds            | 390
# -RECORD 6--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:42
#  date               | 2005-11-15
#  node               | R24-M0-N5-C:J09-U11
#  date_and_time      | 2005-11-15 05:47:42.470164
#  node_repeated      | R24-M0-N5-C:J09-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 2 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected over 389 seconds
#  day                | Tuesday
#  seconds            | 389
# -RECORD 7--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 13:47:48
#  date               | 2005-11-15
#  node               | R12-M1-N5-C:J07-U11
#  date_and_time      | 2005-11-15 05:47:48.368267
#  node_repeated      | R12-M1-N5-C:J07-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected over 391 seconds
#  day                | Tuesday
#  seconds            | 391
# -RECORD 8--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 14:09:21
#  date               | 2005-11-15
#  node               | R22-M0-N6-C:J02-U01
#  date_and_time      | 2005-11-15 06:09:21.402169
#  node_repeated      | R22-M0-N6-C:J02-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 3 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 1675 seconds
#  day                | Tuesday
#  seconds            | 1675
# -RECORD 9--------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 14:23:09
#  date               | 2005-11-15
#  node               | R12-M0-N4-C:J03-U11
#  date_and_time      | 2005-11-15 06:23:09.027484
#  node_repeated      | R12-M0-N4-C:J03-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 388 seconds
#  day                | Tuesday
#  seconds            | 388
# -RECORD 10-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 14:23:10
#  date               | 2005-11-15
#  node               | R03-M1-N9-C:J13-U01
#  date_and_time      | 2005-11-15 06:23:10.101627
#  node_repeated      | R03-M1-N9-C:J13-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 3 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 389 seconds
#  day                | Tuesday
#  seconds            | 389
# -RECORD 11-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 14:25:42
#  date               | 2005-11-15
#  node               | R36-M0-N7-C:J03-U11
#  date_and_time      | 2005-11-15 06:25:42.782018
#  node_repeated      | R36-M0-N7-C:J03-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 3 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 388 seconds
#  day                | Tuesday
#  seconds            | 388
# -RECORD 12-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-15 15:08:07
#  date               | 2005-11-15
#  node               | R06-M1-N6-C:J15-U01
#  date_and_time      | 2005-11-15 07:08:07.048436
#  node_repeated      | R06-M1-N6-C:J15-U01
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 155 seconds
#  day                | Tuesday
#  seconds            | 155
# -RECORD 13-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:34:49
#  date               | 2005-11-17
#  node               | R77-M1-NA-C:J02-U11
#  date_and_time      | 2005-11-17 05:34:49.625862
#  node_repeated      | R77-M1-NA-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 14-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:34:49
#  date               | 2005-11-17
#  node               | R55-M0-N9-C:J06-U11
#  date_and_time      | 2005-11-17 05:34:49.761766
#  node_repeated      | R55-M0-N9-C:J06-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 15-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:34:49
#  date               | 2005-11-17
#  node               | R55-M0-N9-C:J06-U11
#  date_and_time      | 2005-11-17 05:34:49.895129
#  node_repeated      | R55-M0-N9-C:J06-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 2 tree receiver 2 in re-synch state event(s) (dcr 0x019a) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 16-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:34:50
#  date               | 2005-11-17
#  node               | R72-M1-NB-C:J02-U11
#  date_and_time      | 2005-11-17 05:34:50.036304
#  node_repeated      | R72-M1-NB-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 17-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:34:50
#  date               | 2005-11-17
#  node               | R73-M0-NB-C:J02-U11
#  date_and_time      | 2005-11-17 05:34:50.180055
#  node_repeated      | R73-M0-NB-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 18-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:35:41
#  date               | 2005-11-17
#  node               | R63-M0-NC-C:J02-U11
#  date_and_time      | 2005-11-17 05:35:41.1928
#  node_repeated      | R63-M0-NC-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 1 in re-synch state event(s) (dcr 0x0185) detected over 43 seconds
#  day                | Thursday
#  seconds            | 43
# -RECORD 19-------------------------------------------------------------------------------------------------
#  alert_message_flag | -
#  timestamp          | 2005-11-17 13:35:52
#  date               | 2005-11-17
#  node               | R53-M0-NC-C:J02-U11
#  date_and_time      | 2005-11-17 05:35:52.677865
#  node_repeated      | R53-M0-NC-C:J02-U11
#  message_type       | RAS
#  system_component   | KERNEL
#  level              | INFO
#  message_content    | 1 tree receiver 0 in re-synch state event(s) (dcr 0x01bc) detected over 224 seconds
#  day                | Thursday
#  seconds            | 224
# only showing top 20 rows

# %% [markdown]
# <span style="color:blue">***THE AVERAGE NUMBER OF SECONDS OVER WHICH "RE-SYNCH STATE EVENTS" OCCURRED FOR EACH DAY OF THE WEEK***<span style="color:blue">

# %%
# Calculate the average number of seconds per day for "re-synch state events" in the DataFrame 'extracted_logs_df'.
# Group the DataFrame by the 'day' column and calculate the average of the 'seconds' column for each group.
# The result will be a new DataFrame with two columns: 'day' and 'average_seconds'.
average_seconds_per_day=extracted_logs_df.groupBy("day").agg(avg("seconds").alias("average_seconds"))
average_seconds_per_day.show(truncate=False, vertical=True)
# Out:
# [Stage 10:>                                                         (0 + 6) / 6]
# -RECORD 0-----------------------------
#  day             | Tuesday
#  average_seconds | 8538.424347826087
# -RECORD 1-----------------------------
#  day             | Friday
#  average_seconds | 6954.137299771167
# -RECORD 2-----------------------------
#  day             | Thursday
#  average_seconds | 8412.631868131868
# -RECORD 3-----------------------------
#  day             | Monday
#  average_seconds | 14511.80625
# -RECORD 4-----------------------------
#  day             | Wednesday
#  average_seconds | 11170.689243027888
# -RECORD 5-----------------------------
#  day             | Saturday
#  average_seconds | 17872.340482573727
# -RECORD 6-----------------------------
#  day             | Sunday
#  average_seconds | 16091.967088607595

# %% [markdown]
# **EXECUTION TIME COUNTER STOP- TOTAL EXECUTION TIME GENERATED BELOW**

# %%
#https://docs.python.org/3/library/time.html
#returns the value (in fractional seconds) of a performance counter.It does include time elapsed during sleep and is system-wide.
executiontimeend= time.perf_counter()

# %%
# Calculating the total execution time as  time.perf_counter() returns the absolute value of the counter
# https://stackoverflow.com/questions/25785243/understanding-time-perf-counter-and-time-process-time
totalexecution_time= executiontimeend - executiontimestart
totalexecution_time
# Out:
# 9.01429712800018

# %%
# all the information on the 'spark runtime environment', executors sumamry, jobs and its stages can be found on 'Spark UI'
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.64.4:4044">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
average_seconds_per_day.show()
# Out:
# [Stage 13:>                                                         (0 + 6) / 6]
# +---------+------------------+
# |      day|   average_seconds|
# +---------+------------------+
# |  Tuesday| 8538.424347826087|
# |   Friday| 6954.137299771167|
# | Thursday| 8412.631868131868|
# |   Monday|       14511.80625|
# |Wednesday|11170.689243027888|
# | Saturday|17872.340482573727|
# |   Sunday|16091.967088607595|
# +---------+------------------+
